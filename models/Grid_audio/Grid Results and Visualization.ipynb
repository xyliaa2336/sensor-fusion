# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sensors_ini.rnns.lasagne_utils import save_model, store_in_log, load_model, load_log, replace_updates_nans_with_zero

# One to investigate:
filename = 'lipreading_grid_audio_1_recent'

# Load history from file
history = load_log(filename)

plt.figure(figsize=(14,10))
plt.subplot(2,1,1)
plt.plot(history['train_acc'], '.-')
plt.plot(history['val_acc'], '.-')
#plt.plot(history['val_no_aud_acc'], '.-')
#plt.plot(history['val_no_vid_acc'], '.-')
plt.legend(['Accuracy', 'Validation Accuracy'],loc='lower right')
plt.title('Peak Training Accuracy: {:.2f}%  Peak Validation Accuracy: {:.2f}%'.format(np.max(history['train_acc']),np.max(history['val_acc'])))
plt.grid(which='both')

plt.subplot(2,1,2)
plt.semilogy(history['train_err'], '.-')
plt.semilogy(history['val_err'], '.-')
#plt.semilogy(history['val_no_aud_err'], '.-')
#plt.semilogy(history['val_no_vid_err'], '.-')
plt.legend(['Loss', 'Validation Loss'])
plt.grid(which='both')
plt.savefig('grid_accuracy_history.png')

# %%
import numpy as np
import theano.tensor as T
import theano
import glob
from lipreading_utils import find_data_mean, find_data_std, HDF5LipReadingIterator, HDF5LipReadingIterator_events,\
                             ftensor5, get_train_and_val_fn, vocab_size, print_model_with_data
from lipreading_models import get_dan_original_rnn, get_network,get_dan_original_audio
import h5py

#h5file = '/media/yy/Seagate Expansion Drive1/hwGrid_20 (copy).hdf5'
h5file='/home/yy/thesis/workspace/cochlp_6_17.hdf5'
# Get the same random data split
np.random.seed(42)   
# Get dataset
log = load_log(filename)

# Load dataset
dataset = h5py.File(h5file, "r")

print('Train set size: {} sentences.'.format(len(dataset['train_labels'])))
print('Test set size: {} sentences.'.format(len(dataset['test_labels'])))

# Load network
aud_in   = T.ftensor3('aud_in')
vid_in   = ftensor5('vid_in')
targets  = T.fmatrix('targets')
network = get_dan_original_audio(aud_in)
load_model(filename, network)

# Get data iterator
d = HDF5LipReadingIterator()

# Compile the output fn
print('Compiling output functions...')
train_fn, val_fn, out_fn = get_train_and_val_fn([aud_in], targets, network)
print('Compiled.')

# Load a data
for data in d.flow(dataset, 'train', batch_size=7, shuffle=False, blankout=0):

    aud_in, aud_mask, vid_in, vid_mask, bY = data
    output = out_fn(aud_in)
    err, acc,debug_var2 = val_fn(aud_in, bY)
    break
print('Data prepped and passed through.')
print(acc)
print(debug_var2)
# Out:
# Train set size: 93 sentences.
# Test set size: 7 sentences.
# Compiling output functions...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-50bfc7f0d29b> in <module>()
#      32 # Compile the output fn
#      33 print('Compiling output functions...')
# ---> 34 train_fn, val_fn, out_fn = get_train_and_val_fn([aud_in], targets, network)
#      35 print('Compiled.')
#      36
#
# /home/yy/thesis/workspace/single_branch/Grid_audio/lipreading_utils.py in get_train_and_val_fn(inputs, target_var, network)
#     374     test_loss = test_loss.mean()
#     375
# --> 376     out_fn = get_layer_output_fn(inputs, network)
#     377     fn_inputs = inputs + [target_var]
#     378     train_fn = theano.function(fn_inputs, [loss, train_acc,prediction_thresholded], updates=updates)
#
# /home/yy/thesis/workspace/single_branch/Grid_audio/lipreading_utils.py in get_layer_output_fn(fn_inputs, network)
#     345     for layer in lasagne.layers.get_all_layers(network):
#     346         outs.append(lasagne.layers.get_output(layer, deterministic=True))
# --> 347     out_fn = theano.function(fn_inputs, outs)
#     348     return out_fn
#     349
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     320                    on_unused_input=on_unused_input,
#     321                    profile=profile,
# --> 322                    output_keys=output_keys)
#     323     # We need to add the flag check_aliased inputs if we have any mutable or
#     324     # borrowed used defined inputs
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     478                          accept_inplace=accept_inplace, name=name,
#     479                          profile=profile, on_unused_input=on_unused_input,
# --> 480                          output_keys=output_keys)
#     481
#     482
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1815                    profile=profile,
#    1816                    on_unused_input=on_unused_input,
# -> 1817                    output_keys=output_keys).create(
#    1818             defaults)
#    1819
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1495                         optimizer, inputs, outputs)
#    1496                 else:
# -> 1497                     optimizer_profile = optimizer(fgraph)
#    1498
#    1499                 end_optimizer = time.time()
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in __call__(self, fgraph)
#     100
#     101         """
# --> 102         return self.optimize(fgraph)
#     103
#     104     def add_requirements(self, fgraph):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      88             orig = theano.tensor.basic.constant.enable
#      89             theano.tensor.basic.constant.enable = False
# ---> 90             ret = self.apply(fgraph, *args, **kwargs)
#      91         finally:
#      92             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     229             try:
#     230                 t0 = time.time()
# --> 231                 sub_prof = optimizer.optimize(fgraph)
#     232                 l.append(float(time.time() - t0))
#     233                 sub_profs.append(sub_prof)
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      88             orig = theano.tensor.basic.constant.enable
#      89             theano.tensor.basic.constant.enable = False
# ---> 90             ret = self.apply(fgraph, *args, **kwargs)
#      91         finally:
#      92             theano.tensor.basic.constant.enable = orig
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    2195                         nb = change_tracker.nb_imported
#    2196                         t_opt = time.time()
# -> 2197                         lopt_change = self.process_node(fgraph, node, lopt)
#    2198                         time_opts[lopt] += time.time() - t_opt
#    2199                         if not lopt_change:
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/opt.pyc in process_node(self, fgraph, node, lopt)
#    1771         lopt = lopt or self.local_opt
#    1772         try:
# -> 1773             replacements = lopt.transform(node)
#    1774         except Exception as e:
#    1775             if self.failure_callback is not None:
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/opt.pyc in local_subtensor_merge(node)
#    2837                                          xshape[pos_1],
#    2838                                          slices2[pos_2],
# -> 2839                                          ushape[pos_2]))
#    2840                     pos_2 += 1
#    2841                 else:
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/opt.pyc in merge_two_slices(slice1, len1, slice2, len2)
#    2685         raise ValueError(('First provided slice should actually be of type'
#    2686                          'slice and not an index !'), slice1)
# -> 2687     sl1, reverse1 = get_canonical_form_slice(slice1, len1)
#    2688     sl2, reverse2 = get_canonical_form_slice(slice2, len2)
#    2689
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/subtensor.pyc in get_canonical_form_slice(theslice, length)
#     131         stop, is_stop_constant = analyze(theslice.stop)
#     132         step, is_step_constant = analyze(theslice.step)
# --> 133         length, is_length_constant = analyze(length)
#     134
#     135         if step is None:
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/subtensor.pyc in analyze(x)
#     124                 is_constant = True
#     125             except theano.tensor.NotScalarConstantError:
# --> 126                 x_constant = theano.tensor.extract_constant(x)
#     127                 is_constant = False
#     128             return x_constant, is_constant
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/basic.pyc in extract_constant(x, elemwise, only_process_constants)
#    3364         x = get_scalar_constant_value(x,
#    3365                                       elemwise,
# -> 3366                                       only_process_constants)
#    3367     except NotScalarConstantError:
#    3368         pass
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/basic.pyc in get_scalar_constant_value(orig_v, elemwise, only_process_constants)
#     660                                 get_scalar_constant_value_elemwises):
#     661                     const = [get_scalar_constant_value(i)
# --> 662                              for i in v.owner.inputs]
#     663                     ret = [[None]]
#     664                     v.owner.op.perform(v.owner, const, ret)
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/basic.pyc in get_scalar_constant_value(orig_v, elemwise, only_process_constants)
#     660                                 get_scalar_constant_value_elemwises):
#     661                     const = [get_scalar_constant_value(i)
# --> 662                              for i in v.owner.inputs]
#     663                     ret = [[None]]
#     664                     v.owner.op.perform(v.owner, const, ret)
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/basic.pyc in get_scalar_constant_value(orig_v, elemwise, only_process_constants)
#     713                                 if idx < length + ll:
#     714                                     return get_scalar_constant_value(
# --> 715                                         joined[idx - length])
#     716                                 length += ll
#     717                         except TypeError:
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/var.pyc in __getitem__(self, args)
#     534                     self, *theano.tensor.subtensor.Subtensor.collapse(
#     535                         args,
# --> 536                         lambda entry: isinstance(entry, Variable)))
#     537
#     538     def take(self, indices, axis=None, mode='raise'):
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/op.pyc in __call__(self, *inputs, **kwargs)
#     611         """
#     612         return_list = kwargs.pop('return_list', False)
# --> 613         node = self.make_node(*inputs, **kwargs)
#     614
#     615         if config.compute_test_value != 'off':
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/subtensor.pyc in make_node(self, x, *inputs)
#     476         """
#     477         x = theano.tensor.as_tensor_variable(x)
# --> 478         inputs = tuple(self.my_as_scalar(a) for a in inputs)
#     479
#     480         idx_list = list(self.idx_list)
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/subtensor.pyc in <genexpr>((a,))
#     476         """
#     477         x = theano.tensor.as_tensor_variable(x)
# --> 478         inputs = tuple(self.my_as_scalar(a) for a in inputs)
#     479
#     480         idx_list = list(self.idx_list)
#
# KeyboardInterrupt:

# %%
idx = 5


plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.imshow(aud_in[idx].T, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Audio input')

plt.subplot(1,2,2)
plt.imshow(aud_mask, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Audio Mask')

plt.figure(figsize=(16,8))
# Get padded max length
max_len = vid_in.shape[1]
for i in range(5):
    plt.subplot(2,4,i+1)
    plt.imshow(np.squeeze(vid_in[idx][-(i+1)*10]), cmap='gray')
    plt.title('Frame: end-{}'.format((i+1)*10))
    plt.colorbar()

plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.imshow(vid_mask, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Video Mask')

plt.subplot(1,2,2)
plt.imshow(bY, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Targets')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
print_model_with_data(network, output)

# %%
plt.figure(figsize=(4,4))
plt.imshow(np.squeeze(output[3][117]))

plt.figure(figsize=(16,8))
for i in range(3,10):
    plt.subplot(3,3,i-3+1)
    plt.imshow(output[i][117][0], interpolation='nearest', cmap='gray')
    plt.colorbar()
    plt.title('Layer {}'.format(i))
#plt.savefig('face_through_layers.png')

# %%
idx = 0
print(output[17].shape)
plt.figure(figsize=(16,8))
plt.imshow(output[17][idx].T, interpolation='nearest',aspect='auto')
plt.colorbar()
plt.title('Merged Audio and Video Features')
#plt.savefig('merged_features.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-80452377f06e> in <module>()
#       1 idx = 0
# ----> 2 print(output[17].shape)
#       3 plt.figure(figsize=(16,8))
#       4 plt.imshow(output[17][idx].T, interpolation='nearest',aspect='auto')
#       5 plt.colorbar()
#
# NameError: name 'output' is not defined

# %%
from lipreading_utils import bow_to_said_list
plt.figure(figsize=(16,8))
plt.subplot(2,1,1)
plt.imshow(output[-1], interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Guesses')
plt.ylabel('Example Idx')
plt.subplot(2,1,2)
plt.imshow(bY, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('True Answer')
plt.ylabel('Example Idx')
plt.xlabel('Word')

for idx in range(7):
    # Extract bag-of-words of interest
    bow = output[-1][idx]
    # Find the chosen words
    print('Network guess: {}'.format(' '.join(bow_to_said_list(np.where(bow>0.5, 1, 0)))))
    print('True: {}'.format(' '.join(bow_to_said_list(bY[idx]))))
    #plt.savefig('network_guesses.png')
# Out:
# Network guess: bin green with s 3 again
# True: bin blue at y 3 again soon
# Network guess: bin blue at 1 zero again
# True: bin blue by d 5 soon
# Network guess: bin blue by f again
# True: bin blue by l 9 please soon
# Network guess: green 1 soon
# True: bin blue by q 1 now soon
# Network guess: bin blue at 4 now
# True: bin blue in d 8 now soon
# Network guess: bin blue with e 5 now
# True: bin blue in u 9 now soon
# Network guess: bin green with 7 soon
# True: bin blue with c 7 soon

# %%
bow = output[-1][0]
target_var=bY[0]
print(bow)
test_prediction_thresholded = np.where(output[-1]>0.5, 1.0, 0.0)
print(test_prediction_thresholded)
sum_of_targets = np.sum(bY,axis=1)
test_mean_mismatch_per_example = np.sum(abs(test_prediction_thresholded-bY), axis=1)/sum_of_targets
test_acc = 1.-np.mean(test_mean_mismatch_per_example)
print(test_acc)

# %%
#confusion matrix
#testing
from lipreading_utils import bow_to_said_list
# Load a data
for data in d.flow(dataset, 'test', batch_size=7, shuffle=False, blankout=0.0):
    aud_in, aud_mask, vid_in, vid_mask, bY = data
    output = out_fn(aud_in, vid_in)
    break
plt.figure(figsize=(16,16))
con_mat_train=np.empty([51, 51])
for idx in range(7):
    # Extract bag-of-words of interest
    bow = output[-1][idx]
    # Find the chosen words
    #print('Network guess: {}'.format(' '.join(bow_to_said_list(np.where(bow>0.5, 1, 0)))))
    #print('True: {}'.format(' '.join(bow_to_said_list(bY[idx]))))
    #plt.savefig('network_guesses.png')
    pred=np.where(bow>0.5, 1, 0)
    label=bY[idx]
    #print(pred)
    #print(label)
    pred_ind=np.where(pred==1)
    label_ind=np.where(label==1)
    #print(len(pred_ind[0])-1)
    #print(len(label_ind[0])-1)
    for i in range(len(pred_ind[0])-1):
        
        con_mat_train[pred_ind[0][i]][label_ind[0][i]]=con_mat_train[pred_ind[0][i]][label_ind[0][i]]+1

plt.imshow(con_mat_train, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Testing')

# %%
#confusion matrix
#training
from lipreading_utils import bow_to_said_list
# Load a data
for data in d.flow(dataset, 'train', batch_size=2000, shuffle=True, blankout=0.0):
    aud_in, aud_mask, vid_in, vid_mask, bY = data
    output = out_fn(aud_in, vid_in)
    break
plt.figure(figsize=(16,16))
con_mat_train=np.empty([51, 51])
for idx in range(2000):
    # Extract bag-of-words of interest
    bow = output[-1][idx]
    # Find the chosen words
    #print('Network guess: {}'.format(' '.join(bow_to_said_list(np.where(bow>0.5, 1, 0)))))
    #print('True: {}'.format(' '.join(bow_to_said_list(bY[idx]))))
    #plt.savefig('network_guesses.png')
    pred=np.where(bow>0.5, 1, 0)
    label=bY[idx]
    #print(pred)
    #print(label)
    pred_ind=np.where(pred==1)
    label_ind=np.where(label==1)
    #print(len(pred_ind[0])-1)
    #print(len(label_ind[0])-1)
    for i in range(len(pred_ind[0])-1):
        
        con_mat_train[pred_ind[0][i]][label_ind[0][i]]=con_mat_train[pred_ind[0][i]][label_ind[0][i]]+1

plt.imshow(con_mat_train, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.title('Training')
